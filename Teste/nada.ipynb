# %%
def nada():
    x = 1
    while x < 10:
        print(x, type(x))
        x = x + 1
nada()
# Out:
# 1 <class 'int'>
# 2 <class 'int'>
# 3 <class 'int'>
# 4 <class 'int'>
# 5 <class 'int'>
# 6 <class 'int'>
# 7 <class 'int'>
# 8 <class 'int'>
# 9 <class 'int'>

# %%
print(type(10.0))
# Out:
# <class 'float'>
